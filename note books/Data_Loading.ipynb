# %% [markdown]
# # Retail Intelligence and Consumer Analytics
#
# ## Data Loading Phase
#
# ### Analytics Week 2 Internship Project
#
# Dataset Size : 100,000+ Records
#
# Objective:
# Load and inspect retail sales dataset before preprocessing.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns',None)

# %% [markdown]
# # Read Dataset

# %%
retail_df=pd.read_csv('../data/raw/store_sales_data (2).csv')

# %%
retail_df.head()
# Out:
#   Customer ID Customer Name Last Name Date of Birth     Sales  Year  \
# 0  CUST000001        Curtis    Krause    1973-11-29   3344.69  2023
# 1  CUST000002        Jeremy    Foster    1987-08-30  37094.41  2022
# 2  CUST000003         Ariel    Mccann    1980-12-15  35501.08  2023
# 3  CUST000004       Colleen   Maynard    1989-05-23   8969.33  2021
# 4  CUST000005          Gina    Holden    1957-12-31  35530.44  2021
#
#   Outlet Type City Type              Category of Goods Region Country  \
# 0       Large    Tier 1                      Fast Food   East   India
# 1      Medium    Tier 2                      Fast Food   East   India
# 2       Large   Village            Electric Appliances  South   India
# 3      Medium   Village                 Dairy Products   East   India
# 4       Small   Village  Sessional Fruits & Vegetables   West   India
#
#      Segment  Sales Date   Order ID  Order Date   Ship Date       Ship Mode  \
# ...

# %%
retail_df.tail()
# Out:
#       Customer ID Customer Name Last Name Date of Birth     Sales  Year  \
# 99995  CUST099996        Thomas     Adams    2018-02-02    254.35  2020
# 99996  CUST099997      Clifford    Dillon    1955-08-11    846.66  2019
# 99997  CUST099998         Kelly    Deleon    1991-02-27  12165.34  2019
# 99998  CUST099999         Katie     Moses    1990-10-21  41242.99  2019
# 99999  CUST100000        Jeremy     Combs    2016-12-27  47402.45  2019
#
#       Outlet Type City Type              Category of Goods Region Country  \
# 99995       Large    Tier 1                      Furniture   East   India
# 99996      Medium    Tier 2  Sessional Fruits & Vegetables  North   India
# 99997       Large    Tier 2                      Furniture   East   India
# 99998       Small    Tier 1                      Fast Food  North   India
# 99999      Medium   Village                      Fast Food  North   India
#
#          Segment  Sales Date   Order ID  Order Date   Ship Date  \
# ...

# %%
retail_df.shape
# Out:
# (100000, 25)

# %%
retail_df.columns
# Out:
# Index(['Customer ID', 'Customer Name', 'Last Name', 'Date of Birth', 'Sales',
#        'Year', 'Outlet Type', 'City Type', 'Category of Goods', 'Region',
#        'Country', 'Segment', 'Sales Date', 'Order ID', 'Order Date',
#        'Ship Date', 'Ship Mode', 'State', 'Postal Code', 'Product ID',
#        'Sub-Category', 'Product Name', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 25 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Customer ID        100000 non-null  object
#  1   Customer Name      100000 non-null  object
#  2   Last Name          100000 non-null  object
#  3   Date of Birth      100000 non-null  object
#  4   Sales              100000 non-null  float64
#  5   Year               100000 non-null  int64
#  6   Outlet Type        100000 non-null  object
#  7   City Type          100000 non-null  object
#  8   Category of Goods  100000 non-null  object
#  9   Region             100000 non-null  object
#  10  Country            100000 non-null  object
#  11  Segment            100000 non-null  object
#  12  Sales Date         100000 non-null  object
#  13  Order ID           100000 non-null  object
#  14  Order Date         100000 non-null  object
# ...

# %%
retail_df.describe()
# Out:
#                Sales           Year    Postal Code       Quantity  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    25084.410142    2020.999910  388985.180000       5.493760
# std     14403.187686       1.413757  184192.704685       2.876102
# min       100.570000    2019.000000  110001.000000       1.000000
# 25%     12618.030000    2020.000000  226001.000000       3.000000
# 50%     25134.695000    2021.000000  380001.000000       5.000000
# 75%     37575.850000    2022.000000  560001.000000       8.000000
# max     49999.890000    2023.000000  700001.000000      10.000000
#
#             Discount         Profit
# count  100000.000000  100000.000000
# mean        0.251320    3755.305114
# std         0.144324    2639.852035
# min         0.000000       6.520000
# 25%         0.130000    1651.105000
# 50%         0.250000    3317.450000
# 75%         0.380000    5363.845000
# max         0.500000   14563.670000

# %%
retail_df.sample(5)
# Out:
#       Customer ID Customer Name Last Name Date of Birth     Sales  Year  \
# 89012  CUST089013        Calvin      Cole    1981-02-01   2850.49  2022
# 53192  CUST053193         Nancy     Weber    1977-12-12  28916.82  2023
# 21004  CUST021005          Sean     Moore    1989-02-18  42784.41  2023
# 60037  CUST060038        Joshua     Hogan    2013-06-12   3994.78  2020
# 47254  CUST047255     Stephanie   Griffin    1975-05-09  13620.46  2021
#
#       Outlet Type City Type              Category of Goods Region Country  \
# 89012       Small    Tier 2            Electric Appliances  South   India
# 53192      Medium    Tier 2            Electric Appliances   East   India
# 21004       Small    Tier 2            Electric Appliances   East   India
# 60037       Small    Tier 2  Sessional Fruits & Vegetables  South   India
# 47254       Small    Tier 2  Sessional Fruits & Vegetables   East   India
#
#          Segment  Sales Date   Order ID  Order Date   Ship Date     Ship Mode  \
# ...
